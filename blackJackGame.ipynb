# %% [markdown]
# <a href="https://colab.research.google.com/github/SeanSDarcy2001/CISProgrammingAssignments/blob/main/blackJackGame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
class Player() :

  def __init__(self, Name) :
    self.name = Name
    self.hand = []
    self.chips = 0

  def buyIn(self, amnt) :
    self.chips = amnt

  def bet(self, amnt) :
    if amnt <= self.chips :
      self.chips -= amnt
      return amnt
    else :
      print("Not enough chips!")

  def collect(self, amnt) :
    self.chips += amnt
  
  def amIup(self) :
    return self.chips
  
  def getName(self) :
    return self.name

  def updateHand(self, card) :
    self.hand.append(card)
  
  def getHand(self) :
    value = 0
    numAces = 0
    cards = []
    for i in range(len(self.hand)) :
      cards.append(self.hand[i].getCard())
      value += self.hand[i].value()

      if self.hand[i].card == "Ace" :
        numAces += 1
      
    while(value > 21 and numAces > 0) :
      value -= 10
      numAces -= 1
    return cards, value

  def resetHand(self) :
    self.hand = []

    
class Card() :

  def __init__(self, suit, card) :
    self.suit = suit
    self.card = card

  def getCard(self) :
    return self.card + " of " + self.suit
  
  def value(self) :
    if self.card == "Ace" :
      val = 11
    elif self.card == "2" :
      val = 2
    elif self.card == "3" :
      val = 3
    elif self.card == "4" :
      val = 4
    elif self.card == "5" :
      val = 5
    elif self.card == "6" :
      val = 6
    elif self.card == "7" :
      val = 7
    elif self.card == "8" :
      val = 8
    elif self.card == "9" :
      val = 9
    elif self.card == "10" or self.card == "Jack" or self.card == "Queen" or self.card == "King":
      val = 10
    return val
    
class Deck() :
   def __init__(self) :
     
     self.suits = ["Spades", "Diamonds", "Clubs", "Hearts"]
     self.cards = ["Ace", "2", "3", "4", "5", "6", "7", "8", "9", "10", "Jack", "Queen", "King"]
     self.deck = []

     for suit in self.suits :
       for card in self.cards :
         self.deck.append(Card(suit, card))
    
   def shuffleDeck(self) :
     random.shuffle(self.deck)
  
   def draw(self) :
     return self.deck.pop()

   def cardsLeft(self) :
     return len(self.deck)


class Dealer() :
  def __init__(self, players) :
    self.deck = Deck()
    self.table = players
    self.hand = []
    
  def shuffle(self):
    self.deck.shuffleDeck()
  
  def deal(self) :
    for i in range(2) :
      for players in self.table :
        players.updateHand(self.deck.draw())
      self.hand.append(self.deck.draw())

  def whatsUp(self) :
    return self.hand[1].getCard()

  def whatsDown(self) :
    return self.hand[0].getCard()

  def hit(self, player) :
    player.updateHand(self.deck.draw())
  
  def pay(player, amnt) :
    player.collect(amnt)

  def getHand(self) :
    value = 0
    numAces = 0
    cards = []
    for i in range(len(self.hand)) :
      cards.append(self.hand[i].getCard())
      value += self.hand[i].value()

      if self.hand[i].card == "Ace" :
        numAces += 1
      
    while(value > 21 and numAces > 0) :
      value -= 10
      numAces -= 1
    return cards, value

  def dealerHit(self) :
    self.hand.append(self.deck.draw())

# %%
def whoWon(dealer) :
  for players in dealer.table :
    if players.getHand()[1] > 21 or players.getHand()[1] < dealer.getHand()[1] :
      print(players.getName(), "lost.")
    else :
      print(players.getName(), "wins!")

# %%
sean = Player("Sean")
mustang = Player("Mustang")
mohan = Player("Mohan")



table = [mustang, mohan, sean]
dealer = Dealer(table)
dealer.shuffle()
#dealer.deck.shuffleDeck()

dealer.table[0].buyIn(10)
dealer.table[1].buyIn(10)

bets = []
bets.append(dealer.table[0].bet(2))
bets.append(dealer.table[1].bet(2))

#initial deal
dealer.deal()
for player in dealer.table :
  print("===================")
  print(player.getName())
  print("Hand:", player.getHand()[0])
  print("Value:", str(player.getHand()[1]))

for player in dealer.table :
  busted = False
  stays = False
  while busted == False and stays == False :
    print("===================")
    print("Dealer has: ", dealer.whatsUp(), "faceup.")
    print("===================")
    hand = player.getHand()
    print(hand[0])
    print(player.getName(), "you have", hand[1])
    decision = input('Hit (press h), Stay (press s), Double Down (press d), Split (press 2)')
    if decision == 'h' :
      dealer.hit(player)
      newHand = player.getHand()
      card = newHand[0][-1]
      print(player.getName(), "hits...", card)
      print(player.getName(), "you have", newHand[1])
      if newHand[1] > 21 :
        busted = True
        print(player.getName(), "busted!")
    if decision == 's' :
      stays = True
      print(player.getName(), "stays at ", hand[1])

#now dealer
print("===================")
print("Dealer has", dealer.whatsUp(), "faceup.")
print("Dealer has", dealer.whatsDown(), "underneath.")
value = dealer.getHand()
print("Dealer has ", str(value))

busted = False
while dealer.getHand()[1] < 17 and busted == False :
  dealer.dealerHit()
  print("Dealer hits...", dealer.getHand()[0][-1])
  value = dealer.getHand()[1]
  print("===================")
  print("Dealer has ", str(value))
  if value > 21 :
    print("Dealer busts!")
    busted = True


whoWon(dealer)
# Out:
# ===================
# Mustang
# Hand: ['5 of Hearts', '2 of Diamonds']
# Value: 7
# ===================
# Mohan
# Hand: ['8 of Diamonds', '6 of Spades']
# Value: 14
# ===================
# Sean
# Hand: ['3 of Hearts', '2 of Hearts']
# Value: 5
# ===================
# Dealer has:  5 of Diamonds faceup.
# ===================
# ['5 of Hearts', '2 of Diamonds']
# Mustang you have 7
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)h
# Mustang hits... 8 of Hearts
# Mustang you have 15
# ===================
# Dealer has:  5 of Diamonds faceup.
# ===================
# ['5 of Hearts', '2 of Diamonds', '8 of Hearts']
# Mustang you have 15
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# Mustang stays at  15
# ===================
# Dealer has:  5 of Diamonds faceup.
# ===================
# ['8 of Diamonds', '6 of Spades']
# Mohan you have 14
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# Mohan stays at  14
# ===================
# Dealer has:  5 of Diamonds faceup.
# ===================
# ['3 of Hearts', '2 of Hearts']
# Sean you have 5
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)h
# Sean hits... 2 of Spades
# Sean you have 7
# ===================
# Dealer has:  5 of Diamonds faceup.
# ===================
# ['3 of Hearts', '2 of Hearts', '2 of Spades']
# Sean you have 7
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)h
# Sean hits... 6 of Clubs
# Sean you have 13
# ===================
# Dealer has:  5 of Diamonds faceup.
# ===================
# ['3 of Hearts', '2 of Hearts', '2 of Spades', '6 of Clubs']
# Sean you have 13
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)h
# Sean hits... 3 of Spades
# Sean you have 16
# ===================
# Dealer has:  5 of Diamonds faceup.
# ===================
# ['3 of Hearts', '2 of Hearts', '2 of Spades', '6 of Clubs', '3 of Spades']
# Sean you have 16
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# Sean stays at  16
# ===================
# Dealer has 5 of Diamonds faceup.
# Dealer has Ace of Hearts underneath.
# Dealer has  (['Ace of Hearts', '5 of Diamonds'], 16)
# Dealer hits... 10 of Hearts
# ===================
# Dealer has  16
# Dealer hits... Ace of Clubs
# ===================
# Dealer has  17
# Mustang lost.
# Mohan lost.
# Sean lost.
